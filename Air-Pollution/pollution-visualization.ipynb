# %%
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
gdf_us = gpd.read_file('us-cities-air-pollution.shp')
gdf_us
# Out:
#               City  AQI Value AQI Catego  CO AQI Val CO AQI Cat  Ozone AQI  \
# 0      Punta Gorda         54   Moderate           1       Good         14
# 1          Phoenix         72   Moderate           1       Good          4
# 2          Pontiac         77   Moderate           2       Good         22
# 3      Port Neches         34       Good           1       Good         19
# 4         Portales         77   Moderate           1       Good         34
# ...            ...        ...        ...         ...        ...        ...
# 2863         Union         51   Moderate           1       Good         47
# 2864      Guaynabo         84   Moderate           0       Good         23
# 2865        Reston         60   Moderate           1       Good         40
# 2866  Sand Springs         56   Moderate           1       Good         49
# 2867       El Reno         39       Good           1       Good         39
#
#      Ozone AQ_1  NO2 AQI Va NO2 AQI Ca  PM2.5 AQI PM2.5 AQ_1  \
# ...
